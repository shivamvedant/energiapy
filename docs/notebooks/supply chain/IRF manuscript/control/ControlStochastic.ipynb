# %%
import sys
import pandas
# sys.path.append('/scratch/user/shivam.vedant')
# sys.path.append('/scratch/user/shivam.vedant/src')
sys.path.append("../../../../../src")
import pandas as pd
import random
import matplotlib.pyplot as plt
from matplotlib import rc
from typing import Union, Tuple, List, Dict, Any

from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, VaryingProcess
from energiapy.components.location import Location
from energiapy.components.transport import Transport, VaryingTransport
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.model.solve import solve

from pyomo.environ import ConcreteModel, Var, NonNegativeReals
from pyomo.environ import value as pyo_val

import pickle
import warnings

# %%
schedule_time_intervals = 7  # Number of time intervals in a planning horizon
# _coms = 1
design_exec_scenarios = 1  # Number of execution scenarios
schedule_exec_scenarios = 52
schedule_planning_horizons = 1

M = 1e4  # Big M

design_annualization_factor = 1 / design_exec_scenarios
schedule_annualization_factor = 1 / schedule_planning_horizons

# %%
scheduling_scales = TemporalScale(
    discretization_list=[schedule_planning_horizons, schedule_exec_scenarios, schedule_time_intervals])
scale_iter_list = scheduling_scales.scale_iter(scale_level=len(scheduling_scales.scale) - 1)

# %%
start_idx = 0
end_idx = len(scale_iter_list) - 1

# %%
def build_schedule_model(start_time: tuple, end_time: tuple, scen_df=pd.DataFrame(), eps: float = 1.0):
    default_cap_df = pd.DataFrame(data=[1] * schedule_exec_scenarios)
    default_dem_df = pd.DataFrame(data=[1] * schedule_exec_scenarios * schedule_time_intervals)
    scale_factor = 1
    multiplier = 10

    # Define temporal scales
    scales = TemporalScale(
        discretization_list=[schedule_planning_horizons, schedule_exec_scenarios, schedule_time_intervals],
        start_zero=start_time, end_zero=end_time)

    # ======================================================================================================================
    # Declare resources/commodities
    # ======================================================================================================================
    com1_pur = Resource(name='com1_pur', cons_max=500 * scale_factor, block={'imp': 1, 'urg': 1}, price=0.00,
                        label='Commodity 1 consumed from outside the system',
                        varying=[VaryingResource.DETERMINISTIC_AVAILABILITY])

    com1_in = Resource(name='com1_in', label='Commodity 1 received')
    com1_out = Resource(name='com1_out', label='Commodity 1 to be sent out')

    com1_loc1_out = Resource(name='com1_loc1_out', label='Commodity 1 sent out from location 1')
    com1_loc2_out = Resource(name='com1_loc2_out', label='Commodity 1 sent out from location 2')
    com1_loc3_out = Resource(name='com1_loc3_out', label='Commodity 1 sent out from location 3')
    com1_loc4_out = Resource(name='com1_loc4_out', label='Commodity 1 sent out from location 4')
    com1_loc5_out = Resource(name='com1_loc5_out', label='Commodity 1 sent out from location 5')
    com1_loc6_out = Resource(name='com1_loc6_out', label='Commodity 1 sent out from location 6')
    com1_loc7_out = Resource(name='com1_loc7_out', label='Commodity 1 sent out from location 7')

    com1_sold = Resource(name='com1_sold', revenue=0.00, demand=True, sell=True,
                         label='Commodity 1 sold to outside the system', varying=[VaryingResource.DETERMINISTIC_DEMAND])

    # ======================================================================================================================
    # Declare processes/storage capacities
    # ======================================================================================================================
    com1_process_capacity = 500 * scale_factor * multiplier
    min_process_capacity = 0.01

    com1_procure = Process(name='procure com1', prod_max=com1_process_capacity, conversion={com1_pur: -1, com1_in: 1},
                           capex=25 / scale_factor, vopex=0.01, prod_min=min_process_capacity, label='Procure com1')
    com1_sell = Process(name='sell com1', prod_max=com1_process_capacity, conversion={com1_out: -1, com1_sold: 1},
                        capex=0.1 / scale_factor, vopex=0.01, prod_min=min_process_capacity, label='Sell com1')

    com1_receive_loc1 = Process(name='com1_receive_loc1', prod_max=com1_process_capacity,
                                conversion={com1_loc1_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 1')
    com1_receive_loc2 = Process(name='com1_receive_loc2', prod_max=com1_process_capacity,
                                conversion={com1_loc2_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 2')
    com1_receive_loc3 = Process(name='com1_receive_loc3', prod_max=com1_process_capacity,
                                conversion={com1_loc3_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 3')
    com1_receive_loc4 = Process(name='com1_receive_loc4', prod_max=com1_process_capacity,
                                conversion={com1_loc4_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 4')
    com1_receive_loc5 = Process(name='com1_receive_loc5', prod_max=com1_process_capacity,
                                conversion={com1_loc5_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 5')
    com1_receive_loc6 = Process(name='com1_receive_loc6', prod_max=com1_process_capacity,
                                conversion={com1_loc6_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 6')
    com1_receive_loc7 = Process(name='com1_receive_loc7', prod_max=com1_process_capacity,
                                conversion={com1_loc7_out: -1, com1_in: 1}, capex=0.1 / scale_factor, vopex=0.01,
                                prod_min=min_process_capacity, label='Commodity 1 received from location 7')

    com1_process = Process(name='com1_process', prod_max=com1_process_capacity, conversion={com1_in: -1, com1_out: 1},
                           capex=5 / scale_factor, vopex=0.01, prod_min=min_process_capacity,
                           varying=[VaryingProcess.DETERMINISTIC_CAPACITY],
                           label='Process the commodity through the location')

    com1_store = Process(name='com1_store', prod_max=com1_process_capacity, capex=0.01 / scale_factor, vopex=5,
                         store_min=0.01, store_max=500 * scale_factor * multiplier, prod_min=min_process_capacity,
                         label="Storage capacity of upto 100 units", storage=com1_in, storage_cost=0.02,
                         storage_capex=50 / scale_factor)

    com1_loc1_send = Process(name='com1_loc1_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc1_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 1')
    com1_loc2_send = Process(name='com1_loc2_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc2_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 2')
    com1_loc3_send = Process(name='com1_loc3_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc3_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 3')
    com1_loc4_send = Process(name='com1_loc4_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc4_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 4')
    com1_loc5_send = Process(name='com1_loc5_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc5_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 5')
    com1_loc6_send = Process(name='com1_loc6_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc6_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 6')
    com1_loc7_send = Process(name='com1_loc7_send', prod_max=com1_process_capacity,
                             conversion={com1_out: -1, com1_loc7_out: 1}, capex=0.1 / scale_factor, vopex=0.01,
                             prod_min=min_process_capacity, label='Send commodity one from location 7')

    # ======================================================================================================================
    # Declare locations/warehouses
    # ======================================================================================================================
    loc1 = Location(name='loc1',
                    processes={com1_procure, com1_receive_loc2, com1_receive_loc3, com1_process, com1_store,
                               com1_loc1_send}, label="Location 1", scales=scales, demand_scale_level=2,
                    capacity_scale_level=1, availability_scale_level=1, availability_factor={
            com1_pur: scen_df[[('loc1', 'com1_pur')]].dropna() if ('loc1', 'com1_pur') in scen_df else default_cap_df})

    loc2 = Location(name='loc2',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_receive_loc5, com1_process, com1_store,
                               com1_loc2_send}, label="Location 2", scales=scales, demand_scale_level=2,
                    capacity_scale_level=1, availability_scale_level=1, capacity_factor={
            com1_process: scen_df[[('loc2', 'com1_process')]].dropna() if ('loc2',
                                                                           'com1_process') in scen_df else default_cap_df})

    loc3 = Location(name='loc3',
                    processes={com1_receive_loc1, com1_receive_loc4, com1_process, com1_store, com1_loc3_send},
                    label="Location 3", scales=scales, demand_scale_level=2, capacity_scale_level=1,
                    availability_scale_level=1)

    loc4 = Location(name='loc4', processes={com1_receive_loc2, com1_receive_loc3, com1_receive_loc6, com1_receive_loc5,
                                            com1_receive_loc7, com1_process, com1_store, com1_loc4_send},
                    label="Location 4", scales=scales, demand_scale_level=2, capacity_scale_level=1,
                    availability_scale_level=1, capacity_factor={
            com1_process: scen_df[[('loc4', 'com1_process')]].dropna() if ('loc4',
                                                                           'com1_process') in scen_df else default_cap_df})

    loc5 = Location(name='loc5', processes={com1_receive_loc1, com1_receive_loc2, com1_receive_loc4,
                                            com1_receive_loc7, com1_process, com1_store, com1_loc5_send, com1_sell},
                    label="Location 5", scales=scales, demand_scale_level=2, capacity_scale_level=1,
                    availability_scale_level=1, demand_factor={
            com1_sold: scen_df[[('loc5', 'com1_sold')]].dropna() if ('loc5',
                                                                     'com1_sold') in scen_df else default_dem_df})

    loc6 = Location(name='loc6', processes={com1_procure, com1_receive_loc4, com1_process, com1_store, com1_loc6_send},
                    label="Location 6", scales=scales, demand_scale_level=2, capacity_scale_level=1,
                    availability_scale_level=1, availability_factor={
            com1_pur: scen_df[[('loc6', 'com1_pur')]].dropna() if ('loc6', 'com1_pur') in scen_df else default_cap_df})

    loc7 = Location(name='loc7',
                    processes={com1_receive_loc4, com1_receive_loc5, com1_process, com1_store, com1_loc7_send},
                    label="Location 7", scales=scales, demand_scale_level=2, capacity_scale_level=1,
                    availability_scale_level=1, capacity_factor={
            com1_process: scen_df[[('loc7', 'com1_process')]].dropna() if ('loc7',
                                                                           'com1_process') in scen_df else default_cap_df})

    # ======================================================================================================================
    # Declare transport/trucks
    # ======================================================================================================================

    truck_cap12 = 140 * scale_factor * multiplier
    truck_cap13 = 60 * scale_factor
    truck_cap24 = 100 * scale_factor * multiplier
    truck_cap25 = 60 * scale_factor * multiplier
    truck_cap34 = 60 * scale_factor
    truck_cap45 = 200 * scale_factor * multiplier
    truck_cap47 = 80 * scale_factor * multiplier
    truck_cap64 = 100 * scale_factor * multiplier
    truck_cap75 = 80 * scale_factor * multiplier

    plane_cap15 = 40 * scale_factor

    truck_capmin = 0.01
    plane_capmin = 0.01

    truck12 = Transport(name='truck12', resources={com1_loc1_out}, trans_max=truck_cap12,
                        label='Truck from location 1 to 2', capex=0.5 / scale_factor, vopex=0.05,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck21 = Transport(name='truck21', resources={com1_loc2_out}, trans_max=truck_cap12, label='Truck from location 2 to 1', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck13 = Transport(name='truck13', resources={com1_loc1_out}, trans_max=truck_cap13,
                        label='Truck from location 1 to 3', capex=0.3 / scale_factor, vopex=0.03,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck31 = Transport(name='truck31', resources={com1_loc3_out}, trans_max=truck_cap13, label='Truck from location 3 to 1', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck24 = Transport(name='truck24', resources={com1_loc2_out}, trans_max=truck_cap24,
                        label='Truck from location 2 to 4', capex=0.5 / scale_factor, vopex=0.05,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck42 = Transport(name='truck42', resources={com1_loc4_out}, trans_max=truck_cap24, label='Truck from location 4 to 2', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck25 = Transport(name='truck25', resources={com1_loc2_out}, trans_max=truck_cap25,
                        label='Truck from location 2 to 5', capex=0.3 / scale_factor, vopex=0.03,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck52 = Transport(name='truck52', resources={com1_loc5_out}, trans_max=truck_cap25, label='Truck from location 5 to 2', capex=0.0001, vopex=0.03, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck34 = Transport(name='truck34', resources={com1_loc3_out}, trans_max=truck_cap34,
                        label='Truck from location 3 to 4', capex=0.2 / scale_factor, vopex=0.02,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck43 = Transport(name='truck43', resources={com1_loc4_out}, trans_max=truck_cap34, label='Truck from location 4 to 3', capex=0.0001, vopex=0.02, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck45 = Transport(name='truck45', resources={com1_loc4_out}, trans_max=truck_cap45,
                        label='Truck from location 4 to 5', capex=1 / scale_factor, vopex=0.1, trans_min=truck_capmin,
                        varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck54 = Transport(name='truck54', resources={com1_loc5_out}, trans_max=truck_cap45, label='Truck from location 5 to 4', capex=0.0001, vopex=0.1, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck47 = Transport(name='truck47', resources={com1_loc4_out}, trans_max=truck_cap47,
                        label='Truck from location 4 to 7', capex=0.4 / scale_factor, vopex=0.04,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck74 = Transport(name='truck74', resources={com1_loc7_out}, trans_max=truck_cap47, label='Truck from location 7 to 4', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck64 = Transport(name='truck64', resources={com1_loc6_out}, trans_max=truck_cap64,
                        label='Truck from location 6 to 4', capex=0.5 / scale_factor, vopex=0.05,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck46 = Transport(name='truck46', resources={com1_loc4_out}, trans_max=truck_cap64, label='Truck from location 4 to 6', capex=0.0001, vopex=0.05, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    truck75 = Transport(name='truck75', resources={com1_loc7_out}, trans_max=truck_cap75,
                        label='Truck from location 7 to 5', capex=0.4 / scale_factor, vopex=0.04,
                        trans_min=truck_capmin, varying=[VaryingTransport.DETERMINISTIC_CAPACITY], speed=20)
    # truck57 = Transport(name='truck57', resources={com1_loc5_out}, trans_max=truck_cap75, label='Truck from location 5 to 7', capex=0.0001, vopex=0.04, trans_min=truck_capmin, speed=20, varying=[VaryingTransport.DETERMINISTIC_CAPACITY])

    plane15 = Transport(name='plane15', resources={com1_loc1_out}, trans_max=plane_cap15,
                        label='Plane from location 1 to 5', capex=3 / scale_factor, vopex=0.5,
                        trans_min=plane_capmin, speed=50)

    transport_matrix = [
        [[], [truck12], [truck13], [], [plane15], [], []],  # source: location 1
        [[], [], [], [truck24], [truck25], [], []],  # source: location 2
        [[], [], [], [truck34], [], [], []],  # source: location 3
        [[], [], [], [], [truck45], [], [truck47]],  # source: location 4
        [[], [], [], [], [], [], []],  # source: location 5
        [[], [], [], [truck64], [], [], []],  # source: location 6
        [[], [], [], [], [truck75], [], []]  # source: location 7
    ]

    distance_matrix = [
        [0, 55, 196, M, 130, M, M],
        [55, 0, M, 163, 112, M, 134],
        [196, M, 0, 63, M, M, M],
        [M, 163, 63, 0, 95, 117, 88],
        [130, 112, M, 95, 0, 150, 134],
        [M, M, M, 117, M, 0, M],
        [M, 134, M, 88, 134, M, 0]
    ]

    locset = [loc1, loc2, loc3, loc4, loc5, loc6, loc7]

    sources = locset
    sinks = locset

    network = Network(name='Network', scales=scales, source_locations=sources, sink_locations=sinks,
                      transport_matrix=transport_matrix, distance_matrix=distance_matrix,
                      transport_capacity_scale_level=1,
                      transport_capacity_factor={
                          (loc1, loc2): {truck12: scen_df[[('truck12', 'com1_loc1_out')]].dropna() if ('truck12',
                                                                                                       'com1_loc1_out') in scen_df else default_cap_df},

                          (loc1, loc3): {truck13: scen_df[[('truck13', 'com1_loc1_out')]].dropna() if ('truck13',
                                                                                                       'com1_loc1_out') in scen_df else default_cap_df},

                          (loc1, loc5): {plane15: scen_df[[('plane15', 'com1_loc1_out')]].dropna() if ('plane15',
                                                                                                       'com1_loc1_out') in scen_df else default_cap_df},

                          (loc2, loc4): {truck24: scen_df[[('truck24', 'com1_loc2_out')]].dropna() if ('truck24',
                                                                                                       'com1_loc2_out') in scen_df else default_cap_df},

                          (loc2, loc5): {truck25: scen_df[[('truck25', 'com1_loc2_out')]].dropna() if ('truck25',
                                                                                                       'com1_loc2_out') in scen_df else default_cap_df},

                          (loc3, loc4): {truck34: scen_df[[('truck34', 'com1_loc3_out')]].dropna() if ('truck34',
                                                                                                       'com1_loc3_out') in scen_df else default_cap_df},

                          (loc4, loc5): {truck45: scen_df[[('truck45', 'com1_loc4_out')]].dropna() if ('truck45',
                                                                                                       'com1_loc4_out') in scen_df else default_cap_df},

                          (loc4, loc7): {truck47: scen_df[[('truck47', 'com1_loc4_out')]].dropna() if ('truck47',
                                                                                                       'com1_loc4_out') in scen_df else default_cap_df},

                          (loc6, loc4): {truck64: scen_df[[('truck64', 'com1_loc6_out')]].dropna() if ('truck64',
                                                                                                       'com1_loc6_out') in scen_df else default_cap_df},

                          (loc7, loc5): {truck75: scen_df[[('truck75', 'com1_loc7_out')]].dropna() if ('truck75',
                                                                                                       'com1_loc7_out') in scen_df else default_cap_df},
                          })

    # ======================================================================================================================
    # Declare scenario
    # ======================================================================================================================

    daily_demand = 100 * scale_factor
    demand_penalty = 75
    backlog_penalty = 50

    scenario_demand_dict = {i: {com1_sold: daily_demand} if i == loc5 else {com1_sold: 0} for i in locset}
    demand_penalty_dict = {i: {com1_sold: demand_penalty} if i == loc5 else {com1_sold: 0} for i in locset}
    backlog_penalty_dict = {i: {com1_sold: backlog_penalty} if i == loc5 else {com1_sold: 0} for i in locset}
    # backlog_zero = {'loc5':{'com1_sold': 43}}

    scenario = Scenario(name=f'backlog scenario', scales=scales, scheduling_scale_level=2, network_scale_level=0,
                        purchase_scale_level=2, availability_scale_level=1, demand_scale_level=2,
                        capacity_scale_level=1, network=network, demand=scenario_demand_dict,
                        demand_penalty=demand_penalty_dict, backlog_penalty=backlog_penalty_dict,
                        label='Schedule Scenario with Backlog', annualization_factor=1 / schedule_planning_horizons)

    # ======================================================================================================================
    # Declare model
    # ======================================================================================================================

    problem_mincost = formulate(scenario=scenario,
                                constraints={Constraints.COST, Constraints.TRANSPORT, Constraints.RESOURCE_BALANCE,
                                             Constraints.INVENTORY, Constraints.PRODUCTION, Constraints.BACKLOG,
                                             Constraints.NETWORK, Constraints.PRESERVE_NETWORK}, demand_sign='eq',
                                objective=Objective.COST_W_DEMAND_PENALTY)

    # demand = scenario.demand
    # if isinstance(demand, dict):
    #     if isinstance(list(demand.keys())[0], Location):
    #         try:
    #             demand = {i.name: {
    #                 j.name: demand[i][j] for j in demand[i].keys()} for i in demand.keys()}
    #         except:
    #             pass
    #
    # constraint_demand_lb(instance=problem_mincost, demand=demand, demand_factor=scenario.demand_factor,
    #                      demand_scale_level=scenario.demand_scale_level,
    #                      scheduling_scale_level=scenario.scheduling_scale_level,
    #                      location_resource_dict=scenario.location_resource_dict, epsilon=eps)

    return scenario, problem_mincost

# %%
def fix_design_variables(model2fix, design_model, strict=False):
    var_names = ('X_P','Cap_P','X_S','Cap_S','X_F','Cap_F')

    def _fix_from_vars(src, dst):
        if not (src and dst): return
        for k in src:
            val = pyo_val(src[k])
            if val is not None:
                try: dst[k].fix(val)
                except KeyError:
                    if strict: raise

    def _fix_from_dict(dst, data):
        if not dst or dst.name not in data: return
        for i in dst:
            val = data[dst.name].get(i)
            if val is not None: dst[i].fix(float(val))

    if isinstance(design_model, ConcreteModel):
        src_model = (getattr(design_model.ef, next(iter(n for (n, *_) in design_model.scenarios())), design_model)
                     if hasattr(design_model, 'ef') and hasattr(design_model, 'scenarios') else design_model)
        for n in var_names:
            _fix_from_vars(getattr(src_model, n, None), getattr(model2fix, n, None))
    elif isinstance(design_model, dict):
        for n in var_names:
            _fix_from_dict(getattr(model2fix, n, None), design_model)
    else:
        raise TypeError("design_model must be a ConcreteModel or dict")

# %%
def fix_scheduling_variables(model2fix, current_time_idx: tuple, initial_dict: dict, time_scales, strict: bool = False):
    """
    Fixes past (or earlier) decision/state variables on `model2fix` using values provided in `initial_dict`.

    Parameters
    ----------
    model2fix :         ConcreteModel       Target Pyomo model whose variables will be fixed.
    current_time_idx :  tuple               The current time index (e.g., (year, week, day, slot) or similar).
    initial_dict :      dict                Mapping { var_name -> { index_tuple -> numeric_value } } that supplies the values to fix.
    time_scales :       object              Must provide `time_scales.scale` (sequence describing temporal granularity).
                                            Used to determine how many trailing integer positions in an index correspond to time for comparison.
    strict :            bool, default=False If True, raise KeyError when a key that should be fixed is not present in `initial_dict`. If False, skip silently but issue a warning.

    Notes
    -----
    - Only variables listed in `states` are considered.
    - A key (index tuple) is fixed if its time part is strictly earlier than `current_time_idx`, or if it is equal at the coarse scale but not the exact
      current slot, and we are not at the very first subperiod (non-zero tail).
    """

    states = {
        'P', 'B', 'C', 'S', 'R', 'Inv', 'P_m', 'P_material_m', 'Cap_P', 'Cap_S', 'Capex_process', 'Incidental_process',
        'Capex_storage', 'X_F', 'Cap_F', 'Exp', 'Capex_transport', 'X_P', 'X_S', 'X_P_m', 'Cap_P_m', 'X_P_mm',
        'Demand_penalty', 'Demand_penalty_cost', 'S_demand', 'S_backlog', 'Demand_backlog', 'Demand_backlog_cost'
    }

    vars_to_fix = {v.name: v for v in model2fix.component_objects(Var) if v.name in states}
    zero_tail = (0,) * (len(current_time_idx) - 1)

    def should_fix(idx: tuple) -> bool:
        if idx is None or isinstance(idx, int) or not isinstance(idx, tuple):
            return False
        ints = tuple(e for e in idx if isinstance(e, int))
        L = min(len(time_scales.scale), len(ints))
        if L == 0:
            return False
        tkey = ints[-L:]
        curr = tuple(current_time_idx[:L])
        return (tkey < curr) or (tkey == curr and current_time_idx[1:] != zero_tail and tkey != tuple(current_time_idx))

    for name, var in vars_to_fix.items():
        src_map = initial_dict.get(name, {})
        for k in var.keys():
            if should_fix(k):
                if k not in src_map:
                    msg = f"Missing value for {name}[{k}] in initial_dict"
                    if strict:
                        raise KeyError(msg)
                    else:
                        warnings.warn(msg, UserWarning)
                        continue
                val = src_map[k]
                if val is not None and not var[k].fixed:
                    var[k].fix(float(val))

    print(f"Variables fixed for time {current_time_idx}")

# %%
def print_fixed_variables(instance:ConcreteModel):
    for v in instance.component_objects(Var):
        for index in v:
            if v[index].fixed:
                print(f"{v.name}[{index}]: {v[index].value}")

def get_fixed_variables(instance:ConcreteModel):
    return {v.name: {index: v[index].value for index in v if v[index].fixed} for v in instance.component_objects(Var)}

# %%
# model_record, scenario_record, results_record = dict(), dict(), dict()

# %%
def supply_chain_controller(time_ind: List, norm_varying_dict: Dict, start_at: Union[int, Tuple] = 0,
                            end_at: Union[int, Tuple] = None, initialize_dict: dict = None,
                            # optional: seed fixes for the first solve
                            p_horizon: int = 1, c_horizon: int = 0, lookback: int = 0, design_model=None,
                            eps: float = 1.0):
    """
    Moving-horizon 'control-only' loop:
    - Builds/solves a fresh model each step.
    - Fixes design variables once at t=start.
    - Fixes past decisions from previous iteration via a small dict.
    - Optimizes over a window of length `p_horizon` .

    Returns
    -------
    close_loop_results : dict
        { time_tuple -> { var_name -> {index_tuple -> value} } }
    """
    if c_horizon > p_horizon:
        raise ValueError("c_horizon must be <= p_horizon")
    c_horizon = c_horizon or p_horizon

    # Resolve start/end indices whether user passed tuple or integer
    idx_of = lambda x: time_ind.index(x) if isinstance(x, tuple) else int(x)
    start_idx = idx_of(start_at)
    end_idx = idx_of(end_at if end_at is not None else len(time_ind) - 1)
    if end_idx < start_idx:
        raise ValueError("end_at must be >= start_at")

    close_loop_results = {}
    prev_packet = initialize_dict or {}  # carry-over fixes between iterations

    for t in range(start_idx, end_idx + 1, 1):
        t0 = max(0, t - lookback)
        t1 = min(t + p_horizon, end_idx)

        scen_df = pd.concat([pd.Series(norm_varying_dict[k][t]) for k in norm_varying_dict], axis=1,
                            keys=list(norm_varying_dict.keys()))
        
        print(scen_df)
        
        scenario, model = build_schedule_model(start_time=time_ind[t0], end_time=time_ind[t1], eps=eps, scen_df=scen_df)
        
        # if t >= time_ind.index((0,14,0)):
        #     model.Exp['loc6','loc4','truck64','com1_loc6_out', time_ind[t][0], time_ind[t][1], time_ind[t][2]].fix(40)
        # 
        # scenario_record[time_ind[t]] = scenario
        # model_record[time_ind[t]] = model

        # Fix design vars only once (at the first iteration)
        if t == start_idx and design_model is not None:
            fix_design_variables(model2fix=model, design_model=design_model)

        # Fix past decisions from the previous iteration (or initialize_dict on the first pass)
        if prev_packet:
            fix_scheduling_variables(model2fix=model, current_time_idx=time_ind[t], initial_dict=prev_packet,
                                     time_scales=scenario.scales, strict=True)

        # Solve
        result = solve(scenario=scenario, instance=model, solver='gurobi', name=f"MILP_{time_ind[t]}")
        # results_record[time_ind[t]] = result
        model.write('model_for_cost.lp')
        
        if result.output['termination'] == 'infeasible':
            print(f"\n### Model infeasible at time {time_ind[t]} - stopping controller loop ###\n")
            return close_loop_results, result, model, scenario

        # Extract values (small, serializable packet)
        packet = {v.name: v.extract_values() for v in model.component_objects(Var)}
        close_loop_results[time_ind[t]] = packet
        prev_packet = packet  # becomes the fixes for the next iteration

        print(f"\n##### Finished {time_ind[t]} of {time_ind[end_idx]} #####\n")

    return close_loop_results, result, model, scenario

# %%
with open(f'../ncl/output_32_00_Backlog_ncl.pkl', 'rb') as file:
    load_output_dict = pickle.load(file)

design_scen = list(load_output_dict.keys())[0]

# %%
load_output_dict[design_scen]
# Out:
# {'P': {('loc1', 'com1_loc1_send', 0, 0, 0): 475.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 1): 475.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 2): 130.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 3): 130.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 4): 130.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 5): 130.0,
#   ('loc1', 'com1_loc1_send', 0, 0, 6): 130.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 1, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 2, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 3, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 4, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 5, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 6, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 7, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 8, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 9, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 10, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 1): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 2): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 3): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 4): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 5): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 11, 6): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 0): 160.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 1): 200.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 2): 200.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 3): 200.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 12, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 13, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 14, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 15, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 16, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 17, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 18, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 19, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 20, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 21, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 22, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 23, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 24, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 25, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 26, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 27, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 28, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 29, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 30, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 31, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 32, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 33, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 34, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 35, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 36, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 37, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 38, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 39, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 40, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 41, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 42, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 43, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 44, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 45, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 46, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 47, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 2): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 3): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 4): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 5): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 48, 6): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 0): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 1): 100.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 2): 40.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 3): 40.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 4): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 5): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 49, 6): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 0): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 1): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 2): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 3): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 4): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 5): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 50, 6): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 0): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 1): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 2): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 3): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 4): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 5): 0.0,
#   ('loc1', 'com1_loc1_send', 0, 51, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 0, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 1, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 2, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 3, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 4, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 5, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 6, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 7, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 8, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 9, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 10, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 11, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 12, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 13, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 14, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 15, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 16, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 17, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 18, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 19, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 20, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 21, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 22, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 23, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 24, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 25, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 26, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 27, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 28, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 29, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 30, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 31, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 32, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 33, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 34, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 35, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 36, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 37, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 38, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 39, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 40, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 41, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 42, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 43, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 44, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 45, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 46, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 47, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 48, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 49, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 50, 6): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 0): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 1): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 2): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 3): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 4): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 5): 0.0,
#   ('loc1', 'com1_loc2_send', 0, 51, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 0, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 1, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 2, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 3, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 4, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 5, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 6, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 7, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 8, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 9, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 10, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 11, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 12, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 13, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 14, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 15, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 16, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 17, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 18, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 19, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 20, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 21, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 22, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 23, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 24, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 25, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 26, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 27, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 28, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 29, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 30, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 31, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 32, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 33, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 34, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 35, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 36, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 5): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 37, 6): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 0): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 1): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 2): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 3): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 4): 0.0,
#   ('loc1', 'com1_loc3_send', 0, 38, 5): 0.0,
#   ...},
#  'B': {('loc1', 'com1_pur', 0, 0, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 0, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 1, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 2, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 3, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 4, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 5, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 6, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 7, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 1): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 2): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 3): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 4): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 5): 0.0,
#   ('loc1', 'com1_pur', 0, 8, 6): 0.0,
#   ('loc1', 'com1_pur', 0, 9, 0): 0.0,
#   ('loc1', 'com1_pur', 0, 9, 1): 0.0,
# ...
#   ('loc2', 'com1_sold', 0, 34, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 35, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 36, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 37, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 38, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 39, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 40, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 41, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 42, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 43, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 44, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 45, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 46, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 47, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 48, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 49, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 50, 6): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 0): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 1): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 2): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 3): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 4): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 5): 0.0,
#   ('loc2', 'com1_sold', 0, 51, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 0, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 1, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 2, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 3, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 4, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 5, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 6, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 7, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 8, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 9, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 10, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 11, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 12, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 13, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 14, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 15, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 16, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 17, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 18, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 19, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 20, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 21, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 22, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 23, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 24, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 25, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 26, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 27, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 28, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 29, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 30, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 31, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 32, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 33, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 34, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 35, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 36, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 5): 0.0,
#   ('loc3', 'com1_sold', 0, 37, 6): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 0): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 1): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 2): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 3): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 4): 0.0,
#   ('loc3', 'com1_sold', 0, 38, 5): 0.0,
#   ...},
#  'Demand_backlog_cost_location': {('loc1', 'com1_sold', 0): 0.0,
#   ('loc2', 'com1_sold', 0): 0.0,
#   ('loc3', 'com1_sold', 0): 0.0,
#   ('loc4', 'com1_sold', 0): 0.0,
#   ('loc5', 'com1_sold', 0): 174750.0,
#   ('loc6', 'com1_sold', 0): 0.0,
#   ('loc7', 'com1_sold', 0): 0.0},
#  'Demand_backlog_cost_network': {('com1_sold', 0): 174750.0},
#  'first_stage_cost': {None: 79405.0}}

# %%
with open(f'../cl_step2/ssoln_256_00_Backlog_cl_step2_new.pkl', 'rb') as file:
    load_ssoln_dict = pickle.load(file)

# %%
print(*[(k,v) for k,v in load_ssoln_dict.items() if v != 0 and 'Cap_F' in k], sep='\n')
# Out:
# ('Cap_F[loc1,loc2,truck12,0]', 445.0)
# ('Cap_F[loc1,loc3,truck13,0]', 60.0)
# ('Cap_F[loc1,loc5,plane15,0]', 30.0)
# ('Cap_F[loc2,loc4,truck24,0]', 40.0)
# ('Cap_F[loc2,loc5,truck25,0]', 445.0)
# ('Cap_F[loc3,loc4,truck34,0]', 60.0)
# ('Cap_F[loc4,loc5,truck45,0]', 100.0)
# ('Cap_F[loc4,loc7,truck47,0]', 70.0)
# ('Cap_F[loc6,loc4,truck64,0]', 100.0)
# ('Cap_F[loc7,loc5,truck75,0]', 70.0)

# %%
sum(v for k,v in load_ssoln_dict.items() if v != 0 and 'Cap_P' in k and 'com1_store' in k)
# Out:
# 157.1818181818182

# %%
with open(f'../cl/ssoln_128_00_Backlog_cl.pkl', 'rb') as file:
    load_ssoln_dict_cl = pickle.load(file)

# %%
print(*[(k,v) for k,v in load_ssoln_dict.items() if v != 0 and 'Cap_F' in k], sep='\n')
# Out:
# ('Cap_F[loc1,loc2,truck12,0]', 445.0)
# ('Cap_F[loc1,loc3,truck13,0]', 60.0)
# ('Cap_F[loc1,loc5,plane15,0]', 30.0)
# ('Cap_F[loc2,loc4,truck24,0]', 40.0)
# ('Cap_F[loc2,loc5,truck25,0]', 445.0)
# ('Cap_F[loc3,loc4,truck34,0]', 60.0)
# ('Cap_F[loc4,loc5,truck45,0]', 100.0)
# ('Cap_F[loc4,loc7,truck47,0]', 70.0)
# ('Cap_F[loc6,loc4,truck64,0]', 100.0)
# ('Cap_F[loc7,loc5,truck75,0]', 70.0)

# %%
def create_list(n_total: int, n_start: int = 0, n_end: int = 0, disrupt_val:float=0.0) -> list:
    n_start = n_start or n_total
    n_end = n_end or n_total
    return [1] * n_start + [disrupt_val] * (n_end - n_start) + [1] * (n_total - n_end)

# %%
# disruption_time_idx = 14  # Disruption starts here
# early_warning = 1  # Information about the disruption is relayed to the model
# capacity_factor_dict = {
#     k: [1] * (disruption_time_idx - 1) + [int(i < disruption_time_idx - early_warning - 1)] * (
#                 schedule_exec_scenarios - disruption_time_idx + 1) for i in range(schedule_exec_scenarios)
#     for k in range(i * schedule_time_intervals, (i + 1) * schedule_time_intervals)
# }

# %%
cap_dis_start_idx = 14  # Disruption starts here
cap_early_warning = 1  # Information about the disruption is relayed to the model
capacity_factor_dict = {
    k: [1] * (cap_dis_start_idx - 1) + [int(i < cap_dis_start_idx - cap_early_warning - 1)] * (
                schedule_exec_scenarios - cap_dis_start_idx + 1) for i in range(schedule_exec_scenarios)
    for k in range(i * schedule_time_intervals, (i + 1) * schedule_time_intervals)
}

# %%
truck_dis_start_idx = 14
truck_dis_end_idx = 26
truck_early_warning = 2

prefix = [1] * (truck_dis_start_idx - 1)
normal_vec = prefix + [1] * (schedule_exec_scenarios - truck_dis_start_idx + 1)
drop_vec   = prefix + [0.75] * (truck_dis_end_idx - truck_dis_start_idx + 1) \
                     + [1] * (schedule_exec_scenarios - truck_dis_end_idx)

threshold = truck_dis_start_idx - truck_early_warning - 1

truck_factor_dict = {
    k: (normal_vec if i < threshold else drop_vec)
    for i in range(schedule_exec_scenarios)
    for k in range(i * schedule_time_intervals, (i + 1) * schedule_time_intervals)
}

# %%
disruption_dict = dict()
disruption_dict[('loc2', 'com1_process')] = capacity_factor_dict
disruption_dict[('truck45', 'com1_loc4_out')] = truck_factor_dict

# %%
close_loop_results, end_result, end_model, end_scenario = supply_chain_controller(time_ind=scale_iter_list, norm_varying_dict=disruption_dict, p_horizon=20, design_model=load_output_dict[design_scen], end_at=(0,0,2))
